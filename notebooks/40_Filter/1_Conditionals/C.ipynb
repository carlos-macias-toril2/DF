# %%
import pandas as pd
path = '/workspaces/DF/data/topics/sports/olympic-games/all.csv'
df_olympics = pd.read_csv(path)
df_olympics
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
mask = df_olympics['Team'] == 'Spain'

mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Team, Length: 271116, dtype: bool

# %%
df_olympics[mask]
# Out:
#             ID                         Name Sex   Age  Height  Weight   Team  \
# 139         51            Nstor Abad Sanjun   M  23.0   167.0    64.0  Spain
# 140         51            Nstor Abad Sanjun   M  23.0   167.0    64.0  Spain
# 141         51            Nstor Abad Sanjun   M  23.0   167.0    64.0  Spain
# 142         51            Nstor Abad Sanjun   M  23.0   167.0    64.0  Spain
# 143         51            Nstor Abad Sanjun   M  23.0   167.0    64.0  Spain
# ...        ...                          ...  ..   ...     ...     ...    ...
# 270819  135443  Haritz Zunzunegui Echevarra   M  26.0   168.0    60.0  Spain
# 270820  135444    Juan Zunzunegui Guimerans   M  24.0   177.0    70.0  Spain
# 270821  135444    Juan Zunzunegui Guimerans   M  28.0   177.0    70.0  Spain
# 270891  135471           Jos Zurera Alberca   M  22.0   162.0    52.0  Spain
# 270892  135471           Jos Zurera Alberca   M  26.0   162.0    52.0  Spain
#
# ...

# %%
mask1 = df_olympics['Age'] > 60
mask1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Age, Length: 271116, dtype: bool

# %%
df_olympics[mask1]
# Out:
#             ID                  Name Sex   Age  Height  Weight           Team  \
# 2392      1337          Olof Ahlberg   M  71.0     NaN     NaN         Sweden
# 3944      2278     Emilio lava Sautu   M  63.0     NaN     NaN          Spain
# 7433      4160    Robert Day Andrews   M  75.0     NaN     NaN  United States
# 7496      4188       Ferdinand Andri   M  65.0     NaN     NaN        Austria
# 7497      4188       Ferdinand Andri   M  65.0     NaN     NaN        Austria
# ...        ...                   ...  ..   ...     ...     ...            ...
# 266215  133192  Charles Morris Young   M  62.0     NaN     NaN  United States
# 266216  133192  Charles Morris Young   M  62.0     NaN     NaN  United States
# 266217  133192  Charles Morris Young   M  62.0     NaN     NaN  United States
# 266218  133192  Charles Morris Young   M  62.0     NaN     NaN  United States
# 266219  133192  Charles Morris Young   M  62.0     NaN     NaN  United States
#
# ...

# %%
df_olympics[mask & mask1]
# Out:
#             ID               Name Sex   Age  Height  Weight   Team  NOC  \
# 3944      2278  Emilio lava Sautu   M  63.0     NaN     NaN  Spain  ESP
# 250714  125573  Daniel Vzquez Daz   M  66.0     NaN     NaN  Spain  ESP
#
#               Games  Year  Season      City             Sport  \
# 3944    1952 Summer  1952  Summer  Helsinki          Shooting
# 250714  1948 Summer  1948  Summer    London  Art Competitions
#
#                                                  Event Medal
# 3944       Shooting Men's Rapid-Fire Pistol, 25 metres   NaN
# 250714  Art Competitions Mixed Painting, Unknown Event   NaN

# %%
mask_francia = df_olympics['Year'].between(2000,2010)
mask_francia
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115     True
# Name: Year, Length: 271116, dtype: bool

# %%
df_olympics[mask_francia]
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 28           9              Antti Sami Aalto   M  26.0   186.0    96.0
# 31          12             Jyri Tapani Aalto   M  31.0   172.0    70.0
# 33          13            Minna Maarit Aalto   F  34.0   159.0    55.5
# 57          18          Timo Antero Aaltonen   M  31.0   189.0   130.0
# 72          20            Kjetil Andr Aamodt   M  30.0   176.0    85.0
# ...        ...                           ...  ..   ...     ...     ...
# 271105  135565      Fernando scar Zylberberg   M  23.0   168.0    76.0
# 271106  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271115  135571            Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#              Team  NOC        Games  Year  Season            City  \
# ...

# %%
mask_francia2 = df_olympics['Team'].isin(['France','Spain'])
mask_francia2
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Team, Length: 271116, dtype: bool
